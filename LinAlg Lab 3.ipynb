# %% [markdown]
# # Linear Algebra for CpE
# ## Laboratory 3 : Linear Combination and Vector Spaces

# %% [markdown]
# Coded and submitted by:<br>
# Panelo, Bryan V.<br>
# 58011

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Activity

# %% [markdown]
# ### Task 1

# %% [markdown]
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the  linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$ A = C\cdot [3,2],  B = C\cdot [5,4] $$

# %% [markdown]
# $$A = C\cdot  \begin{bmatrix} 3\\2 \\\end{bmatrix} ,
#  B = C\cdot \begin{bmatrix}  5\\4 \\\end{bmatrix} $$

# %%
vectA =np.array([3,2])
vectB =np.array([5,4])
vectR = vectA + vectB

# %%
c = np.arange(-10,10,0.25) #making a sample of some numbers (a range that accepts 3 parameters)

plt.scatter(c*vectA[0],c*vectA[1], color='red', label="Vector A") #multiplying to the unit vectors
plt.scatter(c*vectB[0],c*vectB[1], color='blue', label="Vector B") #multiplying to the unit vectors
plt.scatter(c*vectR[0],c*vectR[1], color='green', label="Vector R")

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.xlim(-20,20) #x limit
plt.ylim(-20,20) #y limit
plt.axhline(y=0, color='black') #y plot
plt.axvline(x=0, color='black') #x plot
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Task 2

# %% [markdown]
# Try making three unque spans using different linear combinations . In your methodology discuss the different functions that you have used, the  linear equations and vector form of span, and the flowchart for declaring and displaying span. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the span visualization you made. You should use the cells below for displaying the equation markdows using LaTeX and your code.

# %% [markdown]
# $$
# S = C_1 \cdot [2,4], C_2 \cdot [1,3]
# $$

# %% [markdown]
# $$S = \begin{Bmatrix} C_1 \cdot\begin{bmatrix} 2\\4 \\\end{bmatrix},
# C_2 \cdot \begin{bmatrix} 1\\3 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([2,4])
vectB = np.array([1,3])
R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R) #creates a range of 2D values of R and R
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
plt.scatter(R*vectA[0],R*vectA[1], color='red', label="Vector R")
plt.scatter(spanRx,spanRy, s=5, alpha=0.50, color='blue', label="SpanX,Y")

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# $$
# S = C_1 \cdot [1,12], C_2 \cdot [16,1]
# $$

# %% [markdown]
# $$S = \begin{Bmatrix} C_1 \cdot\begin{bmatrix} 1\\12 \\\end{bmatrix},
# C_2 \cdot \begin{bmatrix} 16\\2 \\\end{bmatrix}\end{Bmatrix} $$

# %%
VectA = np.array([1,12])
vectB = np.array([16,1])
R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)  #creates a range of 2D values of R and R
vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0] 
spanRy = c1*vectA[1] + c2*vectB[1] 
plt.scatter(R*vectA[0],R*vectA[1], color='red', label="VectR")
plt.scatter(spanRx,spanRy, s=5, alpha=0.75, color='blue', label="SpanX,Y")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# $$
# S = C_1 \cdot [0,1], C_2 \cdot [1,0]
# $$

# %% [markdown]
# $$S = \begin{Bmatrix} C_1 \cdot\begin{bmatrix} 0\\1 \\\end{bmatrix},
# C_2 \cdot \begin{bmatrix} 1\\0 \\\end{bmatrix}\end{Bmatrix} $$

# %%
VectA = np.array([0,1])
vectB = np.array([1,0])
R = np.arange(-10,10,1)

c1, c2 = np.meshgrid(R,R)  #creates a range of 2D values of R and R
vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0] 
spanRy = c1*vectA[1] + c2*vectB[1] 
plt.scatter(R*vectA[0],R*vectA[1], color='red', label="VectR")
plt.scatter(spanRx,spanRy, s=5, alpha=0.75, color='blue', label="SpanX,Y")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.legend()
plt.show()
